# %%
from pathlib import Path
source_path = "/kaggle/input/kidney-ct-scan/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"
data_dir = Path('../input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/')

# Path to train directory (Fancy pathlib...no more os.path!!)
train_dir = data_dir / 'CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone'
train_dir
# Out:
# WindowsPath('../input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone')

# %% [markdown]
# !pip install opendatasets

# %%
import opendatasets as od
datasets="https://www.kaggle.com/datasets/nazmul0087/ct-kidney-dataset-normal-cyst-tumor-and-stone"

# %%
od.download(datasets)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:
#   haeunkim93
# Your Kaggle Key:
#   ········
# Dataset URL: https://www.kaggle.com/datasets/nazmul0087/ct-kidney-dataset-normal-cyst-tumor-and-stone
# ...
# 100%|██████████| 1.52G/1.52G [00:30<00:00, 53.1MB/s]

# %%
import torch
from torch.utils.data import Dataset,DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import wandb

# %% [markdown]
# def customImageDataset(Dataset):
#     def __init__(self,data_path,transform):
#         self.path=data_path
#         self.transform=transform
#         self.image_normal=glob.glob(self.path + "\\Normal\\*.jpg")
#         self.image_cyst=glob.glob(self.path + "\\Cyst\\*.jpg")
#         self.image_stone=glob.glob(self.path + "\\Stone\\&.jpg")
#         self.image_tumor=glob.glob(self.path + "\\Tumor\\*.jpg")
#         self.img=self.image_cyst+self.image_normal+self.image_stone+self.image_tumor
#         self.image_list=[]
#         for img_path in self.img:
#             self.image_list.append(Image.open(img_path))
#     def __len__(self):
#         return len(self.img)
#     def __get__item(self,idx):
#         img=self.image_list[idx]
#         return img

# %%
os.getcwd()
# Out:
# 'C:\\Users\\haeun\\Downloads\\24spring\\medicine(special_topic)\\final_project'

# %%
trans=transforms.Compose([transforms.Resize((224,224)),
                          transforms.ToTensor(),
                          transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
                         ])

# %%
train_dataset=datasets.ImageFolder(root="dataset/train",transform=trans)
valid_dataset=datasets.ImageFolder(root="dataset/val",transform=trans)
test_dataset=datasets.ImageFolder(root="dataset/test",transform=trans)

# %% [markdown]
# classes=data.classes
# classes
# from torchdata.datapipes.iter import IterableWrapper
# len_data=len(data)
# print(len_data)

# %% [markdown]
# len_train=int(len_data*0.8)
#
# len_valid=len_data-len_train
#
# train_dataset,valid_dataset=torch.utils.data.random_split(data,[len_train,len_valid])
# print(len(train_dataset))
# len_valid=int(total*0.5)
# len_test=total-len_valid
# valid_dataset,test_dataset=torch.utils.data.random_split(valid_dataset,[len_valid,len_test])

# %%
train_dataset= imagefolder.ImageFolder('./test', transform=test_transform)

# %%
train_loader=DataLoader(train_dataset,batch_size=16,shuffle=True)
valid_loader=DataLoader(valid_dataset,batch_size=16,shuffle=False)
test_loader=DataLoader(test_dataset,batch_size=16,shuffle=False)

# %%
from torchvision.models import resnet50, ResNet50_Weights

model2 = resnet50(weights=ResNet50_Weights.IMAGENET1K_V2)

# %%
import torch.nn as nn
model2.fc=nn.Linear(2048,4)

# %%
classifier=model2

# %% [markdown]
# !pip install split-folders

# %%
from ultralytics import YOLO
import splitfolders

# %%
model = YOLO('yolov8n-cls.pt')

# %% [markdown]
# splitfolders.ratio("data", output="dataset",seed=831, ratio=(.8, 0.1,0.1))

# %%
import torch
device =torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(device)
# Out:
# cuda

# %%
classes=(train_dataset.classes)
import numpy as np
fig = plt.figure(figsize=(30, 30))

images,labels=next(iter(train_loader))
img = images / 2 + 0.5 
grid_img = torchvision.utils.make_grid(img)
plt.imshow(grid_img.permute(1, 2, 0),cmap='gray')
plt.title(' '.join('%5s, ' % classes[labels[j]] for j in range(len(labels))))
# Out:
# Text(0.5, 1.0, 'Normal,  Normal,   Cyst,  Tumor,  Tumor,  Normal,  Tumor,   Cyst,  Tumor,  Normal,  Tumor,   Cyst,  Normal,  Stone,  Normal,  Normal, ')

# %%
def train(model,optimizer,dataset,epochs,loss_fu):
    model=model.to(device)
    for epoch in epochs:
        for

# %%
pip uninstall ultralytics
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
model=model.to(device)
model.train(data="dataset", epochs=100)
# Out:
# engine\trainer: task=classify, mode=train, model=yolov8n-cls.pt, data=dataset, epochs=3, time=None, patience=100, batch=16, imgsz=224, save=True, save_period=-1, cache=False, device=cuda:0, workers=8, project=None, name=train8, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynami
# ...
